# %%
import pandas as pd
imdb_title_basics = pd.read_pickle('cleaned_data/imdb_title_basics.pkl')
imdb_title_crew = pd.read_pickle('cleaned_data/imdb_title_crew.pkl')
imdb_title_ratings = pd.read_pickle('cleaned_data/imdb_title_ratins.pkl')
tn_movie_budgets = pd.read_pickle('cleaned_data/tn_movie_budgets.pkl')

# %% [markdown]
# Merging all data into one

# %%
imdb_title_basics.head()
# Out:
#      imdb_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year                  genres
# 0        2013    [Action,Crime,Drama]
# 1        2019       [Biography,Drama]
# 2        2018                 [Drama]
# 3        2018          [Comedy,Drama]
# 4        2017  [Comedy,Drama,Fantasy]

# %%
imdb_title_crew.head()
# Out:
#      imdb_id                          directors                 writers
# 0  tt0285252                        [nm0899854]             [nm0899854]
# 2  tt0462036                        [nm1940585]             [nm1940585]
# 3  tt0835418                        [nm0151540]  [nm0310087, nm0841532]
# 4  tt0878654  [nm0089502, nm2291498, nm2292011]             [nm0284943]
# 6  tt0996958                        [nm2286991]  [nm2286991, nm2651190]

# %%
title_basic_crew = imdb_title_basics.join(imdb_title_crew.set_index('imdb_id'), on='imdb_id',how='left')

# %%
title_basic_crew.head()
# Out:
#      imdb_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year                  genres               directors  \
# 0        2013    [Action,Crime,Drama]             [nm0712540]
# 1        2019       [Biography,Drama]                     NaN
# 2        2018                 [Drama]             [nm0000080]
# 3        2018          [Comedy,Drama]             [nm0611531]
# 4        2017  [Comedy,Drama,Fantasy]  [nm0765384, nm0749914]
#
#                                         writers
# 0  [nm0023551, nm1194313, nm0347899, nm1391276]
# 1                                           NaN
# ...

# %%
basic_crew_ratings = title_basic_crew.join(imdb_title_ratings.set_index('imdb_id'), on='imdb_id',how='left')

# %%
imdb_title_ratings.head()
# Out:
#       imdb_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
basic_crew_ratings.head()
# Out:
#      imdb_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year                  genres               directors  \
# 0        2013    [Action,Crime,Drama]             [nm0712540]
# 1        2019       [Biography,Drama]                     NaN
# 2        2018                 [Drama]             [nm0000080]
# 3        2018          [Comedy,Drama]             [nm0611531]
# 4        2017  [Comedy,Drama,Fantasy]  [nm0765384, nm0749914]
#
#                                         writers  averagerating  numvotes
# 0  [nm0023551, nm1194313, nm0347899, nm1391276]            7.0      77.0
# ...

# %%
tn_movie_budgets.head()
# Out:
#   release_date                                primary_title  \
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# 3   2015-05-01                      Avengers: Age of Ultron
# 4   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 5   2015-12-18         Star Wars Ep. VII: The Force Awakens
#
#    production_budget  domestic_gross  worldwide_gross
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747
# 5          306000000       936662225       2053311220

# %%
merged_data = basic_crew_ratings.join(tn_movie_budgets.set_index('primary_title'),on='primary_title',how='left')

# %%
merged_data.shape
# Out:
# (130233, 13)

# %% [markdown]
# Removed all NA values

# %%
new = merged_data.dropna()

# %%
table = pd.pivot_table(new, columns = ['genres'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#     113                 result, _ = self.grouper.aggregate(
# --> 114                     block.values, how, axis=agg_axis, min_count=min_count)
#     115             except NotImplementedError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in aggregate(self, values, how, axis, min_count)
#     547         return self._cython_operation('aggregate', values, how, axis,
# --> 548                                       min_count=min_count)
#     549
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     452                                           "supported for the 'how' argument")
# ...
