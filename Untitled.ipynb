# %%
import pandas as pd

# %%
data = pd.read_csv('the-movies-dataset/movies_metadata.csv', encoding='latin')
# Out:
# /Applications/anaconda3/envs/learn-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,2,5,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df = data.drop(['title','homepage','original_language','overview','popularity','adult','belongs_to_collection','poster_path','runtime','spoken_languages','status','tagline','runtime','video','vote_average','vote_count'],axis=1)

# %%
df.tail(10)
# Out:
#                                  budget  \
# 45456                         260000000
# 45457                         260000000
# 45458                         260000000
# 45459                         270000000
# 45460                         280000000
# 45461                         300000000
# 45462                         380000000
# 45463  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 45464  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
# 45465  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
#
#                                                   genres       id    imdb_id  \
# 45456  [{'id': 16, 'name': 'Animation'}, {'id': 10751...    38757  tt0398286
# 45457  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...    49529  tt0401729
# 45458  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...   335988  tt3371366
# 45459  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...     1452  tt0348150
# 45460  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...    99861  tt2395427
# ...
